# %% [markdown]
# # Kinematics
#
# Kinematics is a branch of classical mechanics that studies how things move without studying the forces required to produce the motion.
#
# **Reference Frames** - Vectors such as position, velocity, and acceleration are always described in the context of a reference frame.
#
# **Homogenous Transform** - A way to express vectors expressed in one reference frame to another.  It is a 4x4 matrix that captures the relative rotations and translations between two frames.
#
# Forward and Inverse Kinimatic problem:
# 	Forward: Joint Space --> **Forward Kinematics** --> Cartesian Space
# 	Inverse; Cartesian space --> **Inverse Kinematics** -- Joint Space
#
# **Degrees of Freedom:** minimum # of variables that are required to define the position or configuration of a mechanism in space.

# %% [markdown]
# How many coordinates do you need to describe a system of 2 points connected by a rigid rod?
#
# ![connected_points.png](attachment:connected_points.png)
#
# Answer: 3.  The x,y and angle.

# %% [markdown]
# ### 2-DoF Arm
#
# ** Example Function ** joint1_angle is the angle counterclockwise from the link1 axis

# %%
def compute_arm_config(link1_length, link2_length, joint0_angle, joint1_angle):
    # compute the (x, y) position of the p1 joint and the end effector at p2.  

    joint1_x = link1_length * np.cos(joint0_angle)
    joint1_y = link1_length * np.sin(joint0_angle)
    p2_x = joint1_x + link2_length * np.cos(joint0_angle + joint1_angle)
    p2_y = joint1_y + link2_length * np.sin(joint0_angle + joint1_angle)

    return joint1_x, joint1_y, p2_x, p2_y

# %% [markdown]
# ![two-dof-labeled.png](attachment:two-dof-labeled.png)
#
# ** 2-DoF Manipulator ** Base = (0,0) If we know the length of each arm, we only need to know the angle of the first arm and the angle of the second arm from the first arm axis.

# %% [markdown]
# ** Generalized Coordinates ** - refers to the parameters that describe the configuration of the system relative to some reference configuration.
#
# ### DoF = number of independent generalized coordinates
#
# ** configuration space or joint space ** which is the set of all possible configurations a manipulator can have.
#
# ** RULE: ** for any serial manipulator using only *prismatic* or *revolute* joints the **DoF** is always equal to the *number* of joints.
#
# When manipulators have more **Dof** that what is required for the task then the manipulator is considered **Kinematically Redundant**

# %% [markdown]
# ## Serial Manipulator Applications
#
# **Workspace** Defines the set of all points reachablel by the end effector.  Subdivided into two regions:
# * *reachable workspace* implied by workspace
# * *dextrous workspace* usable workspace by end effector
#
# ##### Cartesian Manipulator(PPP)
# ![l01-05-l-properties-of-the-principal-manipulator-types-01.png](attachment:l01-05-l-properties-of-the-principal-manipulator-types-01.png)
#
# ##### Cylindrical Manipulator (RPP)
# ![l01-05-l-properties-of-the-principal-manipulator-types-02.png](attachment:l01-05-l-properties-of-the-principal-manipulator-types-02.png)
#
# ##### Anthropomorphic Manipulator (RRR)
# ![l01-05-l-properties-of-the-principal-manipulator-types-03.png](attachment:l01-05-l-properties-of-the-principal-manipulator-types-03.png)
#
# ##### SCARA (RRP)
# Selectively Compliant Assembly Robot Arm
# ![l01-05-l-properties-of-the-principal-manipulator-types-05.png](attachment:l01-05-l-properties-of-the-principal-manipulator-types-05.png)
#
# ##### Spherical (RRP)
# ![l01-05-l-properties-of-the-principal-manipulator-types-04.png](attachment:l01-05-l-properties-of-the-principal-manipulator-types-04.png)

# %% [markdown]
# ### Parallel Manipulator - or - Stewart Platform
# several computer controlled serial chains to support a single platform.
#
# ![220px-Hexapod0a.png](attachment:220px-Hexapod0a.png)
